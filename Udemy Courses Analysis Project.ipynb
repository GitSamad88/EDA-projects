# %%
#!pip3 install streamline
# !pip3 install streamlit
# Out:
# ...
#      ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/9.7 MB 991.0 kB/s eta 0:00:10
#      ---------------------------------------- 0.1/9.7 MB 871.5 kB/s eta 0:00:11
#       --------------------------------------- 0.2/9.7 MB 1.2 MB/s eta 0:00:08
#      - -------------------------------------- 0.3/9.7 MB 1.2 MB/s eta 0:00:08
#      - -------------------------------------- 0.3/9.7 MB 1.2 MB/s eta 0:00:08
#      - -------------------------------------- 0.3/9.7 MB 1.1 MB/s eta 0:00:09
#      - -------------------------------------- 0.4/9.7 MB 1.1 MB/s eta 0:00:09
#      - -------------------------------------- 0.5/9.7 MB 1.2 MB/s eta 0:00:08
#      - -------------------------------------- 0.5/9.7 MB 1.2 MB/s eta 0:00:08
#      - -------------------------------------- 0.5/9.7 MB 1.2 MB/s eta 0:00:08
#      -- ------------------------------------- 0.6/9.7 MB 1.1 MB/s eta 0:00:09
# ...

# %%
import streamlit as st

# %%
A=st.write("Hello world")

# %%
print(A)
# Out:
# None
